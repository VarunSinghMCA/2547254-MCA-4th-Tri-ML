# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# check if the libraries are imported successfully
pd.__version__
np.__version__
# Out:
# '2.3.3'
